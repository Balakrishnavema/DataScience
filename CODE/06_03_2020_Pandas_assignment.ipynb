# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Balakrishna_Vema\\Documents\\Data science\\Code'

# %%
import pandas as pd
import numpy as np
import math as ma

# %%
#load the csv file of customer data
customer_details = pd.read_csv('bank_market.csv.csv')
customer_details
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
#check customer's avarage age
cust_avg_age = np.mean(customer_details["age"])
cust_avg_age
# Out:
# 40.93621021432837

# %%
#check customer max age
cust_max_age = np.max(customer_details["age"])
cust_max_age
# Out:
# 95

# %%
#check customer min age
cust_min_age = np.min(customer_details["age"])
cust_min_age
# Out:
# 18

# %%
#check customer max balance
cust_max_balance = np.max(customer_details["balance"])
cust_max_balance
# Out:
# 102127

# %%
#check customer mean balance
cust_avg_blns = np.mean(customer_details['balance'])
cust_avg_blns
# Out:
# 1362.2720576850766

# %%
#check customer min balance
cust_min_blns = np.min(customer_details["balance"])
cust_min_blns
# Out:
# -8019

# %%
#customer 
col_customers = ['Cust_num', 'a.age','job','marital','education','default1',
                 'balance','housing','loan','contact','day','month','duration',
                 'campaign','pdays','previous','poutcome','y']

# %%
customer_details1 = pd.read_csv(r'bank_market.csv.csv',names=col_customers )

# %%
customer_details1
# Out:
#        Cust_num a.age           job   marital  education default1  balance  \
# 0      Cust_num   age           job   marital  education  default  balance
# 1             1    58    management   married   tertiary       no     2143
# 2             2    44    technician    single  secondary       no       29
# 3             3    33  entrepreneur   married  secondary       no        2
# 4             4    47   blue-collar   married    unknown       no     1506
# ...         ...   ...           ...       ...        ...      ...      ...
# 45207     45207    51    technician   married   tertiary       no      825
# 45208     45208    71       retired  divorced    primary       no     1729
# 45209     45209    72       retired   married  secondary       no     5715
# 45210     45210    57   blue-collar   married  secondary       no      668
# 45211     45211    37  entrepreneur   married  secondary       no     2971
#
# ...

# %%
defualt_cust = np.where(customer_details1["default1"] == 'yes')

# %%
type('a.age')
# Out:
# str

# %%
defualt_cust
# Out:
# (array([    8,    80,   339,   420,   459,   509,   563,   573,   597,
#           637,   690,   768,   806,   839,   853,   885,   933,   934,
#           942,  1117,  1170,  1198,  1200,  1224,  1260,  1326,  1336,
#          1365,  1419,  1589,  1590,  1654,  1666,  1690,  1735,  1759,
#          1768,  1778,  1815,  1823,  1849,  1897,  1925,  1945,  1994,
#          2048,  2051,  2083,  2088,  2100,  2114,  2128,  2171,  2172,
#          2242,  2280,  2292,  2327,  2366,  2376,  2385,  2388,  2398,
#          2410,  2552,  2636,  2720,  2749,  2755,  2758,  2797,  2933,
#          2951,  2968,  3034,  3055,  3171,  3196,  3289,  3398,  3439,
#          3464,  3495,  3550,  3726,  3879,  3887,  3946,  3964,  4012,
#          4085,  4096,  4138,  4352,  4358,  4512,  4582,  4631,  4653,
#          4702,  4823,  4898,  4914,  5037,  5146,  5226,  5278,  5354,
#          5392,  5395,  5399,  5417,  5478,  5502,  5536,  5594,  5612,
# ...
