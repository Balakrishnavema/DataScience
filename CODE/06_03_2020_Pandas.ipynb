# %%
#Pandas -> panel structure data
#Pandas are helping to deal with structure data
#it is fixed dimention data like sql, mysql, oracel
#Manyly pandas use for structure data
#pandas will help us to produce the summry statstics of data like : mean, midam
#checking the relationship between two columns each cloumn, 
#improt pandas as pd (to import the pandas package)
#Basic statistics it will go to 1)series, 2) Data frames

# %%
#1. series is one-dimentional labled array like intiger, array

# %%
import numpy as np
import pandas as pd

# %%
abc = pd.Series(["ind","aus","nz","sa","ban","eng"])

# %%
type(abc)
# Out:
# pandas.core.series.Series

# %%
abc
# Out:
# 0    ind
# 1    aus
# 2     nz
# 3     sa
# 4    ban
# 5    eng
# dtype: object

# %%
abc1 = pd.Series([100,200,300,400])

# %%
type(abc1)
# Out:
# pandas.core.series.Series

# %%
abc1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
quntity = [20,40,60,70]

# %%
abc3 = pd.Series(quntity)

# %%
abc3.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
fruits = ["apple", "oranges","banana","gova"]

# %%
abc4 = pd.Series(quntity, index=fruits)
abc4
# Out:
# apple      20
# oranges    40
# banana     60
# gova       70
# dtype: int64

# %%
years = range(2014,2018)

# %%
list(years)
# Out:
# [2014, 2015, 2016, 2017]

# %%
comp1=pd.Series([1000,2000,3000,4000],index=years)
comp2=pd.Series([5000,6000,7000,8000],index=years)
comp3 = pd.Series([9000,10000,11000,12000],index=years)

# %%
pd.concat([comp1,comp2,comp3])
# Out:
# 2014     1000
# 2015     2000
# 2016     3000
# 2017     4000
# 2014     5000
# 2015     6000
# 2016     7000
# 2017     8000
# 2014     9000
# 2015    10000
# 2016    11000
# 2017    12000
# dtype: int64

# %%
pd.concat([comp1,comp2,comp3],axis=1)
# Out:
#          0     1      2
# 2014  1000  5000   9000
# 2015  2000  6000  10000
# 2016  3000  7000  11000
# 2017  4000  8000  12000

# %%
dict = {"Name":["Balakrishna"],"age":[30]}#

# %%
type(dict)
# Out:
# dict

# %%
pd.DataFrame(dict)
# Out:
#           Name  age
# 0  Balakrishna   30

# %%
dict1 = {"Name":["KSR","Data Science","NLP","ML","DL"],"exp":[8,8,5,4,7]}

# %%
pd.DataFrame(dict1)
# Out:
#            Name  exp
# 0           KSR    8
# 1  Data Science    8
# 2           NLP    5
# 3            ML    4
# 4            DL    7

# %%
#index possition chnage 
ordinal = ["Zero","one","two","three","four"]

# %%
pd.DataFrame(dict1,index=ordinal)
# Out:
#                Name  exp
# Zero            KSR    8
# one    Data Science    8
# two             NLP    5
# three            ML    4
# four             DL    7

# %%
abc3.rename({"name":"subject"})
# Out:
# 0    20
# 1    40
# 2    60
# 3    70
# dtype: int64

# %%
abc3 = dict1.(columns={"Name":"Subject"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-221eda4d1a72> in <module>
# ----> 1 abc3 = dict1.rename(columns={"Name":"Subject"})
#
# AttributeError: 'dict' object has no attribute 'rename'

# %%
abc3 = pd.DataFrame(dict1,columns=["exp","Name"])

# %%
abc3
# Out:
#    exp          Name
# 0    8           KSR
# 1    8  Data Science
# 2    5           NLP
# 3    4            ML
# 4    7            DL

# %%
abc3.reindex(index=[0,2,1,4,3])
# Out:
#    exp          Name
# 0    8           KSR
# 2    5           NLP
# 1    8  Data Science
# 4    7            DL
# 3    4            ML

# %%
abc3.reindex(index=[0,2,1,4,3],columns=["Name","exp"])
# Out:
#            Name  exp
# 0           KSR    8
# 2           NLP    5
# 1  Data Science    8
# 4            DL    7
# 3            ML    4

# %%
abc3.columns
# Out:
# Index(['exp', 'Name'], dtype='object')

# %%
list(abc3.columns)
# Out:
# ['exp', 'Name']

# %%
abc3.exp
# Out:
# 0    8
# 1    8
# 2    5
# 3    4
# 4    7
# Name: exp, dtype: int64

# %%
abc3["exp"]
# Out:
# 0    8
# 1    8
# 2    5
# 3    4
# 4    7
# Name: exp, dtype: int64

# %%
abc3.ndim
# Out:
# 2

# %%
abc3["exp"].sum()
# Out:
# 32

# %%
abc3["exp"].cumsum()
# Out:
# 0     8
# 1    16
# 2    21
# 3    25
# 4    32
# Name: exp, dtype: int64

# %%
abc3["loc"]="bangalore"

# %%
abc3
# Out:
#    exp          Name        loc
# 0    8           KSR  bangalore
# 1    8  Data Science  bangalore
# 2    5           NLP  bangalore
# 3    4            ML  bangalore
# 4    7            DL  bangalore

# %%
abc3["area"]=20000

# %%
abc3
# Out:
#    exp          Name        loc   area
# 0    8           KSR  bangalore  20000
# 1    8  Data Science  bangalore  20000
# 2    5           NLP  bangalore  20000
# 3    4            ML  bangalore  20000
# 4    7            DL  bangalore  20000

# %%
print(abc3)
# Out:
#    exp          Name        loc   area
# 0    8           KSR  bangalore  20000
# 1    8  Data Science  bangalore  20000
# 2    5           NLP  bangalore  20000
# 3    4            ML  bangalore  20000
# 4    7            DL  bangalore  20000

# %%
abc3["area1"]=np.where(abc3["exp"]==8,4000,9000)

# %%
abc3
# Out:
#    exp          Name        loc   area  area1
# 0    8           KSR  bangalore  20000   4000
# 1    8  Data Science  bangalore  20000   4000
# 2    5           NLP  bangalore  20000   9000
# 3    4            ML  bangalore  20000   9000
# 4    7            DL  bangalore  20000   9000

# %%
#how to load the external sources
#in pandas, we can import the data from external sources.
#1. flatfiles, CSV, excel, html, json, xml... csv(delimeter seprated file)
#2. servers(databases):mysql, sql, oracel, teradata, hadoop spark

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Balakrishna_Vema\\Documents\\Data science\\Code'

# %%
path = r"C:\\Users\\Balakrishna_Vema\\Documents\\Data science\\Code"
os.chdir(path)
os.getcwd()
# Out:
# 'C:\\Users\\Balakrishna_Vema\\Documents\\Data science\\Code'

# %%
Bank_customers=pd.read_csv('bank_market.csv.csv' )

# %%
Bank_customers
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bdc =np.where(Bank_customers["default"]=="yes")
bdc
# Out:
# (array([    7,    79,   338,   419,   458,   508,   562,   572,   596,
#           636,   689,   767,   805,   838,   852,   884,   932,   933,
#           941,  1116,  1169,  1197,  1199,  1223,  1259,  1325,  1335,
#          1364,  1418,  1588,  1589,  1653,  1665,  1689,  1734,  1758,
#          1767,  1777,  1814,  1822,  1848,  1896,  1924,  1944,  1993,
#          2047,  2050,  2082,  2087,  2099,  2113,  2127,  2170,  2171,
#          2241,  2279,  2291,  2326,  2365,  2375,  2384,  2387,  2397,
#          2409,  2551,  2635,  2719,  2748,  2754,  2757,  2796,  2932,
#          2950,  2967,  3033,  3054,  3170,  3195,  3288,  3397,  3438,
#          3463,  3494,  3549,  3725,  3878,  3886,  3945,  3963,  4011,
#          4084,  4095,  4137,  4351,  4357,  4511,  4581,  4630,  4652,
#          4701,  4822,  4897,  4913,  5036,  5145,  5225,  5277,  5353,
#          5391,  5394,  5398,  5416,  5477,  5501,  5535,  5593,  5611,
# ...

# %%
#Avarage customer balance
cust_avg_blns = np.average(Bank_customers["balance"])
cust_avg_blns
# Out:
# 1362.2720576850766

# %%
#Avarage customer age
cust_avg_age = np.average(Bank_customers["age"])
cust_avg_age
# Out:
# 40.93621021432837

# %%
cust_def

# %%
#Avarage customer balance 
b2 = np.average(Bank_customers["balance"])
b2
# Out:
# 1362.2720576850766

# %%
#mode value of customer balance
b3 = np.mean(Bank_customers["balance"])
b3
# Out:
# 1362.2720576850766

# %%
air.shape
# Out:
# (45211, 18)

# %%
air=pd.read_csv('bank_market.csv.csv',nrows=10) #"nrows 10 it will load only 10 rows"
air
# Out:
#    Cust_num  age           job   marital  education default  balance housing  \
# 0         1   58    management   married   tertiary      no     2143     yes
# 1         2   44    technician    single  secondary      no       29     yes
# 2         3   33  entrepreneur   married  secondary      no        2     yes
# 3         4   47   blue-collar   married    unknown      no     1506     yes
# 4         5   33       unknown    single    unknown      no        1      no
# 5         6   35    management   married   tertiary      no      231     yes
# 6         7   28    management    single   tertiary      no      447     yes
# 7         8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8         9   58       retired   married    primary      no      121     yes
# 9        10   43    technician    single  secondary      no      593     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
air =pd.read_csv("bank_market.csv.csv",nrows=len(list(range(20,40))))
air
# Out:
#     Cust_num  age           job   marital  education default  balance housing  \
# 0          1   58    management   married   tertiary      no     2143     yes
# 1          2   44    technician    single  secondary      no       29     yes
# 2          3   33  entrepreneur   married  secondary      no        2     yes
# 3          4   47   blue-collar   married    unknown      no     1506     yes
# 4          5   33       unknown    single    unknown      no        1      no
# 5          6   35    management   married   tertiary      no      231     yes
# 6          7   28    management    single   tertiary      no      447     yes
# 7          8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8          9   58       retired   married    primary      no      121     yes
# 9         10   43    technician    single  secondary      no      593     yes
# 10        11   41        admin.  divorced  secondary      no      270     yes
# ...

# %%
#for random rows load 
air =pd.read_csv("bank_market.csv.csv",nrows=len(list(range(20,40,2))))
air
# Out:
#    Cust_num  age           job   marital  education default  balance housing  \
# 0         1   58    management   married   tertiary      no     2143     yes
# 1         2   44    technician    single  secondary      no       29     yes
# 2         3   33  entrepreneur   married  secondary      no        2     yes
# 3         4   47   blue-collar   married    unknown      no     1506     yes
# 4         5   33       unknown    single    unknown      no        1      no
# 5         6   35    management   married   tertiary      no      231     yes
# 6         7   28    management    single   tertiary      no      447     yes
# 7         8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8         9   58       retired   married    primary      no      121     yes
# 9        10   43    technician    single  secondary      no      593     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
#skip rows:
air =pd.read_csv("bank_market.csv.csv",skiprows=10,header=None)

# %%
air=pd.read_csv("bank_market.csv.csv", nrow=1,usecols=[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-5a9e73b447e2> in <module>
# ----> 1 air=pd.read_csv("bank_market.csv.csv", nrow=1,usecols=[1])
#
# TypeError: parser_f() got an unexpected keyword argument 'nrow'

# %%
abc=pd.read_csv(r"bank_market.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-100-10cf6633b355> in <module>
# ----> 1 abc=pd.read_csv(r"bank_market.csv")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...
