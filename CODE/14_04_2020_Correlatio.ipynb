# %%
#Covariance:-  tells about direction between two variables dose have a possitive direction or negative direction
#drow back of covariance is must have the same units

# %%
#Correlation:- by standaization the attribute applying the std to covarance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snb

# %%
air = pd.read_csv(r"C:\Users\Balakrishna_Vema\Documents\Data science\Data sets\AirPassengers.csv")

# %%
air.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# 0                           NO                      0.70             YES
# 1                          YES                      0.80             YES
# 2                           NO                      0.90              NO
# 3                           NO                      0.40              NO
# 4                           NO                      0.87              NO
#
#   Technical_issues_ind
# 0                  YES
# ...

# %%
snb.lmplot(x="Passengers", y= "Passengers", data=air)

# %%
air.columns
# Out:
# Index(['Week_num', 'Passengers', 'Promotion_Budget', 'Service_Quality_Score',
#        'Holiday_week', 'Delayed_Cancelled_flight_ind',
#        'Inter_metro_flight_ratio', 'Bad_Weather_Ind', 'Technical_issues_ind'],
#       dtype='object')

# %%
snb.lmplot(x='Passengers', y= 'Promotion_Budget', data=air)

# %%
air1=air._get_numeric_data()

# %%
air1.drop(["Week_num"],axis=1,inplace=True)

# %%
air1
# Out:
#     Passengers  Promotion_Budget  Service_Quality_Score  \
# 0        37824            517356                4.00000
# 1        43936            646086                2.67466
# 2        42896            638330                3.29473
# 3        35792            506492                3.85684
# 4        38624            609658                3.90757
# ..         ...               ...                    ...
# 75       66934            927696                1.07138
# 76       81228           1108254                0.85536
# 77       43288            638162                3.08191
# 78       43834            636636                2.75382
# 79       40852            575008                3.52768
#
#     Inter_metro_flight_ratio
# 0                       0.70
# 1                       0.80
# 2                       0.90
# 3                       0.40
# 4                       0.87
# ..                       ...
# 75                      0.84
# 76                      0.90
# ...

# %%
abc = np.corrcoef(air1["Passengers"],air1["Promotion_Budget"])
print(abc)
# Out:
# [[1.         0.96585103]
#  [0.96585103 1.        ]]

# %%
snb.heatmap(abc,annot=True, square=True)

# %%
def corr_cal(x,y):
    a1= sum((x-np.mean(x))*(y-np.mean(y)))
    xy=(np.std(x)*np.std(y))
    lenght = (len(x)-1)
    cov=a1/lenght
    corr=cov/xy
    print("covariance value",cov)
    print("correlation",corr)

# %%
a= np.array(air1["Passengers"])
b=np.array

# %%
corr_cal(x=np.array(air1["Passengers"]),y=np.array(air1["Promotion_Budget"]))
# Out:
# covariance value 1703250730.0164557
# correlation 0.9780769907746972

# %%
def corr_cal(data,x,y):
    x1=(data[x]-data[x].mean())*(data[y]-data[y].mean())
    lenght=(len(data[x]-1)
                  
    cov= x1/lenght
    std1=data[x].std()
    std2=data[y].std()
    stdr=std1*std2
    corr=cov/stdr
            
    return x1
# Out:
#   File "<ipython-input-47-c439979c555a>", line 5
#     cov= x1/lenght
#       ^
# SyntaxError: invalid syntax

# %%
corr_cal(data=air1,x="Promotion_Budget",y="Passengers")
# Out:
# 0     7.479299e+08
# 1    -1.671741e+07
# 2    -2.386657e+07
# 3     1.064786e+09
# 4     9.649398e+07
#           ...
# 75    6.707142e+09
# 76    1.761514e+10
# 77   -1.856199e+07
# 78   -1.021592e+07
# 79    1.962643e+08
# Length: 80, dtype: float64

# %%
def corr_cal(data,x,y):
    x1=sum((data[x]-data[x].mean())*(data[y]-data[y].mean()))
    leng=(len(data[x]-1)
            cov=x1/leng
    std1=data[x].std()
    std2=data[y].std()
    stdr=std1*std2
    corr=cov/stdr
    return x1
# Out:
#   File "<ipython-input-70-97689ca53ddb>", line 4
#     cov=x1/leng
#       ^
# SyntaxError: invalid syntax

# %%
abc1=air.corr()
abc1
# Out:
#                           Week_num  Passengers  Promotion_Budget  \
# Week_num                  1.000000    0.412820          0.392003
# Passengers                0.412820    1.000000          0.965851
# Promotion_Budget          0.392003    0.965851          1.000000
# Service_Quality_Score    -0.394892   -0.886530         -0.843382
# Inter_metro_flight_ratio  0.188979    0.491947          0.531449
#
#                           Service_Quality_Score  Inter_metro_flight_ratio
# Week_num                              -0.394892                  0.188979
# Passengers                            -0.886530                  0.491947
# Promotion_Budget                      -0.843382                  0.531449
# Service_Quality_Score                  1.000000                 -0.443437
# Inter_metro_flight_ratio              -0.443437                  1.000000

# %%
snb.heatmap(abc1,annot=True,square=True,cmap="Greens",fmt=".2g")

# %%
snb.heatmap(abc1,annot=True,square=True,cmap="coolwarm",fmt=".3g",vmax=1,vmin=-1,center=0)

# %%
snb.heatmap(abc1,annot=True,square=True,cmap="coolwarm",fmt=".3g",vmax=1,vmin=-1,center=0,linewidths=3,linecolor="black")

# %%
matrix=np.triu(air1.corr())
snb.heatmap(air1.corr(),annot=True,mask=matrix)
