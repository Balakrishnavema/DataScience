# %%
#Data types in python 
#1. Numbers 
#2. strings

# %%
#Numbers
#int
a = 10
type(a)
# Out:
# int

# %%
10 + 10
# Out:
# 20

# %%
a = 10
type(a)
# Out:
# int

# %%
b = 10.99
type(b)
# Out:
# float

# %%
a = "bala"
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 4

# %%
abc = "Hello Balakrishna"
abc
# Out:
# 'Hello Balakrishna'

# %%
abc + abc
# Out:
# 'Hello BalakrishnaHello Balakrishna'

# %%
abc+" "+abc
# Out:
# 'Hello Balakrishna Hello Balakrishna'

# %%
import pandas as pd
import numpy as np
import os

# %%
bank_details = pd.read_csv('bank_market.csv.csv')

# %%
bank_details
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank_details[5:9]
# Out:
#    Cust_num  age           job   marital education default  balance housing  \
# 5         6   35    management   married  tertiary      no      231     yes
# 6         7   28    management    single  tertiary      no      447     yes
# 7         8   42  entrepreneur  divorced  tertiary     yes        2     yes
# 8         9   58       retired   married   primary      no      121     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 5   no  unknown    5   may       139         1     -1         0  unknown  no
# 6  yes  unknown    5   may       217         1     -1         0  unknown  no
# 7   no  unknown    5   may       380         1     -1         0  unknown  no
# 8   no  unknown    5   may        50         1     -1         0  unknown  no

# %%
bank_details.iloc[[6,9,10]]
# Out:
#     Cust_num  age         job   marital  education default  balance housing  \
# 6          7   28  management    single   tertiary      no      447     yes
# 9         10   43  technician    single  secondary      no      593     yes
# 10        11   41      admin.  divorced  secondary      no      270     yes
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 6   yes  unknown    5   may       217         1     -1         0  unknown  no
# 9    no  unknown    5   may        55         1     -1         0  unknown  no
# 10   no  unknown    5   may       222         1     -1         0  unknown  no

# %%
bank_details.loc[[2,4,5]]
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 4         5   33       unknown   single    unknown      no        1      no
# 5         6   35    management  married   tertiary      no      231     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no
# 5   no  unknown    5   may       139         1     -1         0  unknown  no

# %%
bank_details.iloc[[2,5,6,9],[1,2,3]]
# Out:
#    age           job  marital
# 2   33  entrepreneur  married
# 5   35    management  married
# 6   28    management   single
# 9   43    technician   single

# %%
bank_details.loc[[2,5,6,9],["Cust_num","age","job"]]
# Out:
#    Cust_num  age           job
# 2         3   33  entrepreneur
# 5         6   35    management
# 6         7   28    management
# 9        10   43    technician

# %%
bank_details.sample(n=10)
# Out:
#        Cust_num  age            job  marital  education default  balance  \
# 18554     18555   40     unemployed  married  secondary      no      488
# 33050     33051   37  self-employed   single    primary      no      235
# 24479     24480   44     management   single   tertiary      no      300
# 35484     35485   35    blue-collar  married    primary      no     1033
# 22011     22012   32     technician   single  secondary      no        0
# 10102     10103   44    blue-collar  married  secondary      no      289
# 6263       6264   36         admin.  married  secondary      no       68
# 15489     15490   30       services  married    unknown      no      -51
# 21043     21044   31     management   single   tertiary      no     2227
# 5077       5078   36  self-employed   single   tertiary      no     4752
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 18554     yes   no  cellular   31   jul       222         4     -1         0
# ...

# %%
bank_details.sample(n=100, replace=True)
# Out:
#        Cust_num  age          job  marital  education default  balance  \
# 31862     31863   33  blue-collar  married    primary      no      331
# 26459     26460   33      student   single   tertiary      no     2904
# 41066     41067   62   management  married   tertiary      no      557
# 16454     16455   32  blue-collar   single  secondary      no      799
# 28497     28498   32   management  married   tertiary      no     2213
# ...         ...  ...          ...      ...        ...     ...      ...
# 25032     25033   31   management  married   tertiary      no      271
# 19078     19079   34  blue-collar   single   tertiary      no       42
# 1513       1514   37     services  married  secondary      no       22
# 30117     30118   26      student   single  secondary      no     1510
# 6225       6226   23  blue-collar   single    primary     yes     -627
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
dup = bank_details.duplicated()
sum(dup==True)
dup1= bank_details[dup==False]

# %%
dup1.shape
# Out:
# (45211, 18)

# %%
comp = pd.read_csv('Complaints.csv')

# %%
comp
# Out:
#         comp_id   month   incident       cust_id  sla status new  \
# 0     318691791  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 1     318691795  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 2     318691807  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 3     318691809  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 4     317997895  12-Jul  7/17/2012  9.282442e+09    ClosedIN SLA
# ...         ...     ...        ...           ...             ...
# 6582  317987723  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6583  317987725  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6584  317987727  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6585  317987729  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6586  317987731  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
#
#                incident type        type severity
# 0     Customer Communication  VAS-OTHERS     High
# 1     Customer Communication  VAS-OTHERS     High
# ...

# %%
dup_comp = comp.duplicated()

# %%
sum(dup_comp==True)
# Out:
# 0

# %%
comp_uniq = comp[dup_comp==False]

# %%
comp_uniq.shape
# Out:
# (6587, 8)

# %%
comp_dup = comp[dup_comp==True]

# %%
comp_dup.shape
# Out:
# (0, 8)

# %%
comp.nunique()
# Out:
# comp_id           6587
# month                1
# incident            31
# cust_id           4855
# sla status new       4
# incident type       61
# type                 6
# severity            15
# dtype: int64

# %%
dup_col = comp["comp_id"].duplicated()

# %%
sum(dup_col==True)
# Out:
# 0

# %%
sum(dup_col==False)
# Out:
# 6587

# %%
dup_col = comp["cust_id"].duplicated()

# %%
dup_col.shape
# Out:
# (6587,)

# %%
sum(dup_col==True)
# Out:
# 1731

# %%
sum(dup_col==False)
# Out:
# 4856

# %%
bill_dup = comp[dup_col==True]
bill_dup.shape
# Out:
# (1731, 8)

# %%
bill_uniq = comp[dup_col==False]
bill_uniq.shape
# Out:
# (4856, 8)
