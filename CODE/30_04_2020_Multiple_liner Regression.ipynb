# %%
#Formula for multiple liner Regression 

#formula: y = B0+B1x1+B2x2+B3x3+.....Bnxn+e

#MAR-> Business Undersatnding(predicting )->Data collection(5000,25)->Dataprearation(missinge values indetification
#outlier identification and tretment & makesure that Dependent variable must be normally distirbuted)
#->EDA(inorder to remove unnecesarry unwanted are the variables which are not significant to the model)other name variable redection 
#/dimension reduction
#1.correlation method
#2.VIF(variance influnce factor/ multicolinarity)
#3. stepwise Regression(forwaed & backward)
#4. lasso regulaization
#5.PCA(Principal component analysis)
#6. Extratree Regression
#7. Random forest regression
#8. XGboost
#9. LGBM boosting method
#10.LDA
#11.Factor analysis


#banking industery using the XGboost and LGBM boosting method (most all are prefering to use LGBM)

#For Categorical(binary)
#1.point Bi-serial correlation
#2.VIF
#3.stepwise Regression
#4.PcA
#5.Extra classification
#6. Random cassifier
#7.XGBoost Classifier
#8.LGBM classiifer
#9.Lasso Regularization
#10. Information value
#11. Chi-Square 


#the Buildin the model
  #p-value <0.05 =>base model is ready  
  #Zvalue/t-value -> x1,x2,x3,x4,x5

#Model metrics
    #F-start->P.value-><0.05
    #Adjg-R2 -> 75%
    #R2 value
    #durbin waston ->1.5 to 2.5
    #jarque bera ->p value-> >0.05
    #skew -> -1to1
    #Omnibus-> as much as more better the model
    #AIc->
    
    #note: any one above points not met that model is not good
    
#fine tune the model
                  #which of the values is less that variable to drop it
                #note: we have to check the abs(t)
        #Drop the less value afte the abc(t) done 
        
#Once model is ready-> we have to compare model(metrix) quition with different data sets 
               #1. RMSE-> Root mean square
               #2.MSE : mean square error
            #3. MAPE: mean absolute percentage
            #4.MAE: mean absolute error
            
#once every this if Good-> we have to Deploy the model 
               #1.flask
            #2.sql code
