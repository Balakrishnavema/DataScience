# %%
import numpy as np
import pandas as pd

# %%
bank = pd.read_csv(r"C:\Users\Balakrishna_Vema\Documents\Data science\Code\bank_market.csv.csv")

# %%
bank
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank[10:20]
# Out:
#     Cust_num  age          job   marital  education default  balance housing  \
# 10        11   41       admin.  divorced  secondary      no      270     yes
# 11        12   29       admin.    single  secondary      no      390     yes
# 12        13   53   technician   married  secondary      no        6     yes
# 13        14   58   technician   married    unknown      no       71     yes
# 14        15   57     services   married  secondary      no      162     yes
# 15        16   51      retired   married    primary      no      229     yes
# 16        17   45       admin.    single    unknown      no       13     yes
# 17        18   57  blue-collar   married    primary      no       52     yes
# 18        19   60      retired   married    primary      no       60     yes
# 19        20   33     services   married  secondary      no        0     yes
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank.head(10)
# Out:
#    Cust_num  age           job   marital  education default  balance housing  \
# 0         1   58    management   married   tertiary      no     2143     yes
# 1         2   44    technician    single  secondary      no       29     yes
# 2         3   33  entrepreneur   married  secondary      no        2     yes
# 3         4   47   blue-collar   married    unknown      no     1506     yes
# 4         5   33       unknown    single    unknown      no        1      no
# 5         6   35    management   married   tertiary      no      231     yes
# 6         7   28    management    single   tertiary      no      447     yes
# 7         8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8         9   58       retired   married    primary      no      121     yes
# 9        10   43    technician    single  secondary      no      593     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank.iloc[[2,4,5,6]]
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 4         5   33       unknown   single    unknown      no        1      no
# 5         6   35    management  married   tertiary      no      231     yes
# 6         7   28    management   single   tertiary      no      447     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no
# 5   no  unknown    5   may       139         1     -1         0  unknown  no
# 6  yes  unknown    5   may       217         1     -1         0  unknown  no

# %%
bank.loc[[2,4,5]] #"iloc & loc both are using for row level operation "
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 4         5   33       unknown   single    unknown      no        1      no
# 5         6   35    management  married   tertiary      no      231     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no
# 5   no  unknown    5   may       139         1     -1         0  unknown  no

# %%
bank.iloc[[2,4,5],[2,5]]
# Out:
#             job default
# 2  entrepreneur      no
# 4       unknown      no
# 5    management      no

# %%
bank.loc[[2,4,5],["job","defualt" ]] #"Iloc:accept the index possition, loc:accept the index label"
# Out:
#             job  defualt
# 2  entrepreneur      NaN
# 4       unknown      NaN
# 5    management      NaN

# %%
bank1 = bank.sample(n=100) #take the Random records"

# %%
bank1.head()
# Out:
#        Cust_num  age          job  marital  education default  balance  \
# 1866       1867   30  blue-collar   single  secondary      no       18
# 10537     10538   37     services  married  secondary      no      -58
# 36956     36957   39       admin.  married  secondary      no        0
# 22054     22055   33   management   single   tertiary      no    20794
# 16953     16954   41       admin.   single  secondary      no        0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 1866       no   no    unknown    9   may       395         1     -1         0
# 10537     yes   no    unknown   16   jun       146         3     -1         0
# 36956      no   no  telephone   12   may       256         4     -1         0
# 22054      no   no   cellular   20   aug       226         5     -1         0
# 16953      no   no  telephone   25   jul       286         2     -1         0
#
#       poutcome   y
# 1866   unknown  no
# 10537  unknown  no
# ...

# %%
bank1 = bank.sample(n=10, replace=True) #replace, it will generate the duplicate records

# %%
bank1
# Out:
#        Cust_num  age           job  marital  education default  balance  \
# 4875       4876   38      services   single    primary      no      471
# 21338     21339   40    management  married   tertiary      no     2935
# 37781     37782   29        admin.  married   tertiary      no      111
# 43249     43250   31    management   single   tertiary      no      147
# 23996     23997   32    technician   single  secondary      no      224
# 6586       6587   23        admin.   single  secondary      no     4681
# 35294     35295   36  entrepreneur  married   tertiary      no     4576
# 31410     31411   43    management  married  secondary      no     3301
# 19952     19953   31    technician   single  secondary      no      942
# 32150     32151   28    management  married  secondary      no      152
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 4875      yes   no   unknown   21   may       180         1     -1         0
# ...

# %%
bill = pd.read_csv(r"C:\Users\Balakrishna_Vema\Documents\Data science\Code\Bill.csv")

# %%
bill.shape
# Out:
# (9462, 7)

# %%
#Duplicate records
#1.row level duplicates 
#2.particuler column level duplicate

# %%
#dataset.duplicate() -> True & False
#1.123 50000 hyd ->false/unique
#2. 123 50000 hyd ture/ duplicate because index possition it is taking

# %%
dup= bill.duplicated() #Duplicate() generates both true and false

# %%
sum(dup==True) #True - duplicate records at row level
# Out:
# 10

# %%
sum(dup==False)
# Out:
# 9452

# %%
bill_unq = bill[dup==False]
bill_unq.shape
# Out:
# (9452, 7)

# %%
bill_dup=bill[dup==True]
bill_dup.shape
# Out:
# (10, 7)

# %%
bill_unq1 = bill.drop_duplicates()
bill_unq1.shape
# Out:
# (9452, 7)

# %%
bill.shape
# Out:
# (9462, 7)

# %%
bill.columns
# Out:
# Index(['cust_id', 'act_active_dt', 'package_id', 'bill_zip',
#        'customer_segment', 'status', 'bill_amt'],
#       dtype='object')

# %%
bill.nunique() #number of unique valuesfor each column
# Out:
# cust_id             9389
# act_active_dt       1297
# package_id           431
# bill_zip             201
# customer_segment      10
# status                 6
# bill_amt            2138
# dtype: int64

# %%
9462-9389
# Out:
# 73

# %%
dup1 = bill["cust_id"].duplicated()

# %%
sum(dup1 == True)
# Out:
# 73

# %%
sum(dup1==False)
# Out:
# 9389

# %%
bill_uniq = bill[dup1 == False]
bill_unq.shape
# Out:
# (9452, 7)

# %%
bill_dup = bill[dup1==True]
bill_dup.shape
# Out:
# (73, 7)

# %%
comp = pd.read_csv(r"C:\Users\Balakrishna_Vema\Documents\Data science\Code\Complaints.csv")

# %%
comp
# Out:
#         comp_id   month   incident       cust_id  sla status new  \
# 0     318691791  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 1     318691795  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 2     318691807  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 3     318691809  12-Jul  7/22/2012  9.243584e+09    ClosedIN SLA
# 4     317997895  12-Jul  7/17/2012  9.282442e+09    ClosedIN SLA
# ...         ...     ...        ...           ...             ...
# 6582  317987723  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6583  317987725  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6584  317987727  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6585  317987729  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
# 6586  317987731  12-Jul  7/17/2012  9.243579e+09  OpenOUT OF SLA
#
#                incident type        type severity
# 0     Customer Communication  VAS-OTHERS     High
# 1     Customer Communication  VAS-OTHERS     High
# ...

# %%
dup_comp_unq = comp.duplicated()
dup_comp_unq.shape
# Out:
# (6587,)

# %%
comp.nunique()
# Out:
# comp_id           6587
# month                1
# incident            31
# cust_id           4855
# sla status new       4
# incident type       61
# type                 6
# severity            15
# dtype: int64

# %%
comp_id = comp["comp_id"].duplicated()
comp_id.shape
sum(comp_id == True)
# Out:
# 0

# %%
comp_id1 = comp["cust_id"].duplicated()
comp_id1.shape
# Out:
# (6587,)

# %%
sum(comp_id1 == True)
# Out:
# 1731

# %%
bank1=bank.head().copy()

# %%
bank1
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 0         1   58    management  married   tertiary      no     2143     yes
# 1         2   44    technician   single  secondary      no       29     yes
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 3         4   47   blue-collar  married    unknown      no     1506     yes
# 4         5   33       unknown   single    unknown      no        1      no
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  unknown    5   may       261         1     -1         0  unknown  no
# 1   no  unknown    5   may       151         1     -1         0  unknown  no
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 3   no  unknown    5   may        92         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank1.drop([3],axis=0)
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 0         1   58    management  married   tertiary      no     2143     yes
# 1         2   44    technician   single  secondary      no       29     yes
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 4         5   33       unknown   single    unknown      no        1      no
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  unknown    5   may       261         1     -1         0  unknown  no
# 1   no  unknown    5   may       151         1     -1         0  unknown  no
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank1.drop([4],axis =0 , inplace=True)

# %%
bank1
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 0         1   58    management  married   tertiary      no     2143     yes
# 1         2   44    technician   single  secondary      no       29     yes
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 3         4   47   blue-collar  married    unknown      no     1506     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  unknown    5   may       261         1     -1         0  unknown  no
# 1   no  unknown    5   may       151         1     -1         0  unknown  no
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 3   no  unknown    5   may        92         1     -1         0  unknown  no

# %%
bank.drop(list(range(10,20)), axis =0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-051ffa8e52e1> in <module>
# ----> 1 bank.drop(list(range(10,20)), axis =0, inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
bank.head(30)
# Out:
#     Cust_num  age           job   marital  education default  balance housing  \
# 0          1   58    management   married   tertiary      no     2143     yes
# 1          2   44    technician    single  secondary      no       29     yes
# 2          3   33  entrepreneur   married  secondary      no        2     yes
# 3          4   47   blue-collar   married    unknown      no     1506     yes
# 4          5   33       unknown    single    unknown      no        1      no
# 5          6   35    management   married   tertiary      no      231     yes
# 6          7   28    management    single   tertiary      no      447     yes
# 7          8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8          9   58       retired   married    primary      no      121     yes
# 9         10   43    technician    single  secondary      no      593     yes
# 20        21   28   blue-collar   married  secondary      no      723     yes
# ...

# %%
bank.columns
# Out:
# Index(['Cust_num', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank1=bank[['cust_num','balance']]
bank1.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-8c4a08b7f6ca> in <module>
# ----> 1 bank1=bank[['cust_num','balance']]
#       2 bank1.shape
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
#cust_num, loan, contact, poutcome, y

# %%
bank
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank4 = bank[["Cust_num", "loan","contact","poutcome","y"]]
bank4.shape
# Out:
# (45201, 5)

# %%
bank4.head()
# Out:
#    Cust_num loan  contact poutcome   y
# 0         1   no  unknown  unknown  no
# 1         2   no  unknown  unknown  no
# 2         3  yes  unknown  unknown  no
# 3         4   no  unknown  unknown  no
# 4         5   no  unknown  unknown  no

# %%
bank4.drop(["loan"],axis=1,inplace=True)
# Out:
# C:\Users\Balakrishna_Vema\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
bank4
# Out:
#        Cust_num    contact poutcome    y
# 0             1    unknown  unknown   no
# 1             2    unknown  unknown   no
# 2             3    unknown  unknown   no
# 3             4    unknown  unknown   no
# 4             5    unknown  unknown   no
# ...         ...        ...      ...  ...
# 45206     45207   cellular  unknown  yes
# 45207     45208   cellular  unknown  yes
# 45208     45209   cellular  success  yes
# 45209     45210  telephone  unknown   no
# 45210     45211   cellular    other   no
#
# [45201 rows x 4 columns]

# %%
bank4.drop(["poutcome","y"],axis=1,inplace=True)
# Out:
# C:\Users\Balakrishna_Vema\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
bank4
# Out:
#        Cust_num    contact
# 0             1    unknown
# 1             2    unknown
# 2             3    unknown
# 3             4    unknown
# 4             5    unknown
# ...         ...        ...
# 45206     45207   cellular
# 45207     45208   cellular
# 45208     45209   cellular
# 45209     45210  telephone
# 45210     45211   cellular
#
# [45201 rows x 2 columns]

# %%
bank
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank1 = bank[["education","default"]].head(10)
bank1
# Out:
#    education default
# 0   tertiary      no
# 1  secondary      no
# 2  secondary      no
# 3    unknown      no
# 4    unknown      no
# 5   tertiary      no
# 6   tertiary      no
# 7   tertiary     yes
# 8    primary      no
# 9  secondary      no

# %%
bank1 = bank[["education","default"]][1000:4000]
bank1
# Out:
#       education default
# 1010    primary      no
# 1011  secondary      no
# 1012  secondary      no
# 1013   tertiary      no
# 1014  secondary      no
# ...         ...     ...
# 4005  secondary      no
# 4006    unknown      no
# 4007    primary      no
# 4008   tertiary      no
# 4009  secondary      no
#
# [3000 rows x 2 columns]

# %%
bank1 = bank.drop(["age"],axis=1)[1000:1010]
bank1
# Out:
#       Cust_num           job   marital  education default  balance housing  \
# 1010      1011   blue-collar   married    primary      no      624     yes
# 1011      1012    technician  divorced  secondary      no     1107     yes
# 1012      1013        admin.    single  secondary      no      573     yes
# 1013      1014    management    single   tertiary      no      406     yes
# 1014      1015      services  divorced  secondary      no      220     yes
# 1015      1016   blue-collar   married  secondary      no     2308     yes
# 1016      1017   blue-collar  divorced    primary      no      139     yes
# 1017      1018        admin.   married  secondary      no      367     yes
# 1018      1019  entrepreneur  divorced    primary      no      278     yes
# 1019      1020   blue-collar   married    primary      no      229     yes
#
#      loan  contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
#Sort: by default pandas sort the data "ASC" order
bank.sort_values("Cust_num")
#exp: 
#  age balance
#1  23  3000
#2  23  4000
#3 24   5000
#4 23   1000

#bank.sort_value(["age", "Balance"])
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank1 = bank.sort_values("age")
bank1
# Out:
#        Cust_num  age      job   marital  education default  balance housing  \
# 41487     41488   18  student    single    unknown      no      108      no
# 44644     44645   18  student    single    unknown      no      438      no
# 41222     41223   18  student    single    unknown      no       35      no
# 42954     42955   18  student    single    unknown      no      108      no
# 40736     40737   18  student    single    primary      no     1944      no
# ...         ...  ...      ...       ...        ...     ...      ...     ...
# 44420     44421   93  retired   married    unknown      no      775      no
# 44262     44263   93  retired   married    unknown      no      775      no
# 31233     31234   94  retired  divorced  secondary      no     1234      no
# 33699     33700   95  retired  divorced    primary      no     2282      no
# 41663     41664   95  retired   married  secondary      no        0      no
#
# ...

# %%
bank2 = bank1.sort_index()

# %%
bank
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 0             1   58    management   married   tertiary      no     2143
# 1             2   44    technician    single  secondary      no       29
# 2             3   33  entrepreneur   married  secondary      no        2
# 3             4   47   blue-collar   married    unknown      no     1506
# 4             5   33       unknown    single    unknown      no        1
# ...         ...  ...           ...       ...        ...     ...      ...
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank1 = bank.sort_values("age")
bank1
# Out:
#        Cust_num  age      job   marital  education default  balance housing  \
# 41487     41488   18  student    single    unknown      no      108      no
# 44644     44645   18  student    single    unknown      no      438      no
# 41222     41223   18  student    single    unknown      no       35      no
# 42954     42955   18  student    single    unknown      no      108      no
# 40736     40737   18  student    single    primary      no     1944      no
# ...         ...  ...      ...       ...        ...     ...      ...     ...
# 44420     44421   93  retired   married    unknown      no      775      no
# 44262     44263   93  retired   married    unknown      no      775      no
# 31233     31234   94  retired  divorced  secondary      no     1234      no
# 33699     33700   95  retired  divorced    primary      no     2282      no
# 41663     41664   95  retired   married  secondary      no        0      no
#
# ...

# %%
bank1 = bank.sort_values("age").reset_index().drop(["index"],axis=1)
bank1.head()
# Out:
#    Cust_num  age      job marital education default  balance housing loan  \
# 0     41488   18  student  single   unknown      no      108      no   no
# 1     44645   18  student  single   unknown      no      438      no   no
# 2     41223   18  student  single   unknown      no       35      no   no
# 3     42955   18  student  single   unknown      no      108      no   no
# 4     40737   18  student  single   primary      no     1944      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 0   cellular    8   sep       169         1     -1         0  unknown  yes
# 1   cellular    1   sep       425         1     -1         0  unknown   no
# 2  telephone   21   aug       104         2     -1         0  unknown   no
# 3   cellular    9   feb        92         1    183         1  success  yes
# 4  telephone   10   aug       122         3     -1         0  unknown   no

# %%
import copy
old_list = [[1,2,3],[2,2,2],[2,3,4]]
new_list = copy.copy(old_list)
old_list
# Out:
# [[1, 2, 3], [2, 2, 2], [2, 3, 4]]

# %%
new_list
# Out:
# [[1, 2, 3], [2, 2, 2], [2, 3, 4]]

# %%
old_list[1][1] = 'AA'
old_list
# Out:
# [[1, 2, 3], [2, 'AA', 2], [2, 3, 4]]

# %%
new_list
# Out:
# [[1, 2, 3], [2, 'AA', 2], [2, 3, 4]]

# %%
new_list[1][2] = "BB"

# %%
old_list
# Out:
# [[1, 2, 3], [2, 'AA', 'BB'], [2, 3, 4]]

# %%
deep_list = copy.deepcopy(old_list)

# %%
deep_list
# Out:
# [[1, 2, 3], [2, 'AA', 'BB'], [2, 3, 4]]

# %%
deep_list[1][2] = 'CC'

# %%
deep_list
# Out:
# [[1, 2, 3], [2, 'AA', 'CC'], [2, 3, 4]]

# %%
old_list
# Out:
# [[1, 2, 3], [2, 'AA', 'BB'], [2, 3, 4]]
