# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
air = pd.read_csv(r"C:\Users\Balakrishna_Vema\Documents\Data science\Data sets\AirPassengers.csv")

# %%
air.shape
# Out:
# (80, 9)

# %% [markdown]
# # Data process:
# 1. duplicate values delete
# 1. missing values
# 2. outliers
# 3. Normal distirbution check

# %%
#1.Duplicate values delete
air.drop_duplicates().shape
# Out:
# (80, 9)

# %%
#1.Missing values
air.isnull().sum()
# Out:
# Week_num                        0
# Passengers                      0
# Promotion_Budget                0
# Service_Quality_Score           0
# Holiday_week                    0
# Delayed_Cancelled_flight_ind    0
# Inter_metro_flight_ratio        0
# Bad_Weather_Ind                 0
# Technical_issues_ind            0
# dtype: int64

# %%
#dependnet variable should be normal distributed 
air[["Passengers"]].skew()
# Out:
# Passengers    1.314496
# dtype: float64

# %%
air[["Promotion_Budget"]].skew()
# Out:
# Promotion_Budget    1.091851
# dtype: float64

# %%
#Relationships
air.corr()
# Out:
#                           Week_num  Passengers  Promotion_Budget  \
# Week_num                  1.000000    0.412820          0.392003
# Passengers                0.412820    1.000000          0.965851
# Promotion_Budget          0.392003    0.965851          1.000000
# Service_Quality_Score    -0.394892   -0.886530         -0.843382
# Inter_metro_flight_ratio  0.188979    0.491947          0.531449
#
#                           Service_Quality_Score  Inter_metro_flight_ratio
# Week_num                              -0.394892                  0.188979
# Passengers                            -0.886530                  0.491947
# Promotion_Budget                      -0.843382                  0.531449
# Service_Quality_Score                  1.000000                 -0.443437
# Inter_metro_flight_ratio              -0.443437                  1.000000

# %%
sns.pairplot(air)

# %%
#liner Regresssion 
import statsmodels.formula.api as smf

# %%
sns.lmplot(x="Promotion_Budget", y="Passengers", data=air)

# %%
model = smf.ols("Passengers~Promotion_Budget",data=air ).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Passengers   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     1084.
# Date:                Tue, 12 May 2020   Prob (F-statistic):           1.66e-47
# Time:                        05:28:05   Log-Likelihood:                -751.34
# No. Observations:                  80   AIC:                             1507.
# Df Residuals:                      78   BIC:                             1511.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
sns.lmplot(x="Promotion_Budget", y="Passengers", data=air)

# %%
stats.pearsonr(air.Passengers, air.Promotion_Budget)
# Out:
# (0.9658510283900134, 1.6573032307996224e-47)

# %%
help(stats.pearsonr)
# Out:
# Help on function pearsonr in module scipy.stats.stats:
#
# pearsonr(x, y)
#     Pearson correlation coefficient and p-value for testing non-correlation.
#
#     The Pearson correlation coefficient [1]_ measures the linear relationship
#     between two datasets.  The calculation of the p-value relies on the
#     assumption that each dataset is normally distributed.  (See Kowalski [3]_
#     for a discussion of the effects of non-normality of the input on the
#     distribution of the correlation coefficient.)  Like other correlation
#     coefficients, this one varies between -1 and +1 with 0 implying no
#     correlation. Correlations of -1 or +1 imply an exact linear relationship.
#     Positive correlations imply that as x increases, so does y. Negative
#     correlations imply that as x increases, y decreases.
#
#     The p-value roughly indicates the probability of an uncorrelated system
#     producing datasets that have a Pearson correlation at least as extreme
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-111-e297f779b1e2> in <module>
# ----> 1 lm.predict(air)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     200
#     201     def _decision_function(self, X):
# --> 202         check_is_fitted(self, "coef_")
#     203
#     204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
# ...
